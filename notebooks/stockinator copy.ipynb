# %%
import yfinance as yf
import pandas as pd
import numpy as np
import datetime

pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 150)

# %%
balance = 10000
tickers = ['SPY', 'VOX', 'VCR', 'VDC', 'VDE', 'VFH', 'VHT', 'VIS', 'VGT', 'VAW', 'VNQ', 'VPU']
period = '3mo'
start = '2018-01-01'
end = '2018-12-31'
interval = '1wk'
year = datetime.datetime.now().date() - datetime.timedelta(days=360)
print(year)
# Out:
# 2019-04-30

# %%
stock_data = yf.download(
    tickers=' '.join(tickers),
    start=start,
    end=end,
    interval=interval,
    group_by="ticker",
    auto_adjust=True,
    threads=True
)
# Out:
# [*********************100%***********************]  12 of 12 completed

# %%
data = pd.DataFrame()
for ticker in tickers:
    #data.loc[:, (ticker, 'Change')] = data[ticker]['Close'] - data[ticker]['Open']
    stock_data.loc[:, (ticker, 'PctChange')] = \
        ((stock_data[ticker]['Close'] - stock_data[ticker]['Open']) / stock_data[ticker]['Open']) * 100
    data[ticker] = stock_data[ticker]['PctChange']
    
data = data.dropna(how='all')
data
# Out:
#                  SPY           VOX       VCR       VDC       VDE       VFH       VHT       VIS       VGT       VAW       VNQ       VPU
# Date
# 2018-01-01  2.083340 -9.189410e-01  2.424708 -0.020525  3.494111  1.008092  2.562614  1.973137  3.637905  3.149550 -2.396433 -2.486284
# 2018-01-08  1.686735  4.746664e-01  3.021989 -0.465249  3.253771  2.852724  1.952873  2.821914  1.066426  0.894306 -3.141945 -2.258348
# 2018-01-15  0.379451 -4.716984e-01  0.060111  2.109590 -1.535850  0.189881  0.932518 -0.875859  0.830658 -0.528949 -0.240814 -0.690092
# 2018-01-22  2.287887  2.490901e+00  2.646902  1.187285  1.387424  1.871183  3.706183  1.187922  1.853015  1.303708  1.090956  1.618126
# 2018-01-29 -3.665226 -1.237784e+00 -3.129208 -4.069610 -6.242294 -2.551832 -4.655673 -3.280432 -3.817990 -5.737020 -3.019629 -2.033026
# 2018-02-05 -4.370090 -5.451522e+00 -3.557482 -4.402908 -6.976742 -3.736115 -5.117884 -4.540100 -3.318849 -3.435567 -3.324636 -2.316283
# ...
